# %%
from webpage.webscraping import scraper

# %%
worker = scraper.Headlines()
# Out:
# [{'full': 'https://www.washingtonpost.com/world/asia_pacific/trump-again-appears-to-take-north-koreas-side-against-his-own-military-allies/2019/08/10/e5e50620-bb6c-11e9-8e83-4e6687e99814_story.html', 'site': 'washingtonpost', 'information': '/world/asia_pacific/trump-again-appears-to-take-north-koreas-side-against-his-own-military-allies/2019/08/10/e5e50620-bb6c-11e9-8e83-4e6687e99814_story.html'}, {'full': 'https://www.washingtonpost.com/resizer/dKsJs5U-mDFIOQ0W8W15tb81kOg\\\\u003d/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/V4M5V7F3OII6TM5UFO3J5DCOHE.jpg', 'site': 'washingtonpost', 'information': '/resizer/dKsJs5U-mDFIOQ0W8W15tb81kOg\\\\u003d/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/V4M5V7F3OII6TM5UFO3J5DCOHE.jpg'}, {'full': 'https://d21rhj7n383afu.cloudfront.net/washpost-production/Reuters/20190810/5d4efab346e0fb000942199b/5d4efb51cff47e00098397dc_1439411933958-zgatlb_t_1565457236217_1920_1080_5400.mp4', 'site': 'cloudfront', 'information': '
# ...

# %%
sample = worker.get_sample(predict_country=True)

# %%
bite = sample.__next__()
# Out:
# predicting on<title data-n-head="true">Trump says he received 'small apology' from Kim Jong Un for missile tests | Fox News</title>
# predicting on<title>North Korea tests 'short-range ballistic missiles' - BBC News</title>
# predicting on<title>North Korea fires off MORE rockets sending two missiles crashing into the sea in protest at US-led war games</title>
# predicting on<title>Defense Chief Esper Wraps Up Asia Trip As Alliance Comes Under Pressure : NPR</title>
# predicting on<title>
#                 China tells UK to back off after minister's call for Hong Kong probe - Reuters</title>
# ...

# %%
print(bite[0]['full'])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-14-8ad0fd356466> in <module>
# ----> 1 print(bite[0]['country'])
#
# ~\Documents\GitHub\News-Map\webpage\data\data_dump\countryapi.py in __str__(self)
#      43     def __str__(self):
#      44         return "<Prediction of {} with a {} percent confidence>".format(str(self.get_country()),
# ---> 45                                                                         str(self.get_confidence()))
#      46
#      47
#
# ~\Documents\GitHub\News-Map\webpage\data\data_dump\countryapi.py in get_confidence(self)
#      20         :return: a number between 0 and 1 of how confident we are of this prediction
#      21         """
# ---> 22         return (self.data.count(self.predicted) / len(self.data)) ** 2
#      23
#      24     def get_country(self):
#
# ZeroDivisionError: division by zero
